# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sales = pd.read_csv("sales.csv")
weather = pd.read_csv("weather.csv")
key = pd.read_csv("key.csv")
print("         Sales")
display(sales.sample(10))
display(sales.info())
display(sales.describe())
print("         Weather")
display(weather.sample(10))
display(weather.info())
display(weather.describe())
print("         Key")
display(key.sample(10))
display(key.info())
display(key.describe())
# Out:
#          Sales
#                date  store_nbr  item_nbr  units
# 256273   2012-02-22         21        86      0
# 4326455  2014-08-21          6         9     48
# 2477115  2013-05-25         22        40      0
# 873311   2012-06-27         10        75      0
# 3587887  2014-02-20         40        35      0
# 3460676  2014-01-23         24        30      0
# 2825710  2013-08-26         31        95      0
# 3214425  2013-11-27         33        88      0
# 2195929  2013-03-20          1        17      0
# 528587   2012-04-18         11         6      0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4617600 entries, 0 to 4617599
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   date       object
#  1   store_nbr  int64
#  2   item_nbr   int64
#  3   units      int64
# dtypes: int64(3), object(1)
# memory usage: 140.9+ MB
# None
#           store_nbr      item_nbr         units
# count  4.617600e+06  4.617600e+06  4.617600e+06
# mean   2.309108e+01  5.600000e+01  9.868756e-01
# std    1.295281e+01  3.204164e+01  9.875798e+00
# min    1.000000e+00  1.000000e+00  0.000000e+00
# 25%    1.200000e+01  2.800000e+01  0.000000e+00
# 50%    2.300000e+01  5.600000e+01  0.000000e+00
# 75%    3.400000e+01  8.400000e+01  0.000000e+00
# max    4.500000e+01  1.110000e+02  5.568000e+03
#          Weather
#        station_nbr        date tmax tmin tavg depart dewpoint wetbulb heat  \
# 14997            1  2014-01-29   25   14   20      M       -4      15   45
# 9347            20  2013-04-19   63   38   51      M       31      43   14
# 17595           19  2014-06-07   78   53   66      2       49      57    0
# 13753           17  2013-11-27   40   23   32      M       12      25   33
# 351             11  2012-01-19   65   32   49     -4       30      40   16
# 19491           15  2014-09-10   71   53   62      1       55      57    3
# 4717            10  2012-08-31   91   80   86      M       75      78    0
# 10235            8  2013-06-03    M    M    M      M        M       M    M
# 15776           20  2014-03-08   55   40   48      M       40      45   17
# 1179             2  2012-03-03   41   28   35      5       33      35   30
#
#       cool sunrise sunset                 codesum snowfall preciptotal  \
# 14997    0       -      -                                M        0.00
# 9347     0       -      -                              0.0        0.00
# 17595    1    0413   1927                      RA      0.0           T
# 13753    0       -      -                              0.0        0.00
# 351      0    0724   1752                              0.0        0.00
# 19491    0    0520   1806                              0.0        0.00
# 4717    21    0603   1851                      BR        M        0.00
# 10235    M       -      -            DZ FG+ FG HZ        M        0.00
# 15776    0       -      -                RA BR HZ      0.0           T
# 1179     0    0620   1739  RA FZRA FG+ FG FZFG BR      0.2        0.53
#
#       stnpressure sealevel resultspeed resultdir avgspeed
# 14997       29.93    30.11         8.0        26      8.4
# 9347        29.47    30.17         7.4        31      9.0
# 17595       29.19    29.93         2.7        10      7.0
# 13753       29.70    30.42         2.4        02      4.3
# 351         30.09    30.14         0.7        35      2.9
# 19491       29.77    30.13         0.6        26      2.3
# 4717        30.12    30.16         4.3        08      5.3
# 10235       29.55        M         2.2        16      2.3
# 15776       29.41    30.09         6.3        33     12.4
# 1179        28.50    29.57         3.6        24      8.5
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20517 entries, 0 to 20516
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   station_nbr  20517 non-null  int64
#  1   date         20517 non-null  object
#  2   tmax         20517 non-null  object
#  3   tmin         20517 non-null  object
#  4   tavg         20517 non-null  object
#  5   depart       20517 non-null  object
#  6   dewpoint     20517 non-null  object
#  7   wetbulb      20517 non-null  object
#  8   heat         20517 non-null  object
#  9   cool         20517 non-null  object
#  10  sunrise      20517 non-null  object
#  11  sunset       20517 non-null  object
#  12  codesum      20517 non-null  object
#  13  snowfall     20517 non-null  object
#  14  preciptotal  20517 non-null  object
#  15  stnpressure  20517 non-null  object
#  16  sealevel     20517 non-null  object
#  17  resultspeed  20517 non-null  object
#  18  resultdir    20517 non-null  object
#  19  avgspeed     20517 non-null  object
# dtypes: int64(1), object(19)
# memory usage: 3.1+ MB
# None
#         station_nbr
# count  20517.000000
# mean      10.549057
# std        5.768533
# min        1.000000
# 25%        6.000000
# 50%       11.000000
# 75%       16.000000
# max       20.000000
#          Key
#     store_nbr  station_nbr
# 2           3            7
# 13         14           16
# 38         39            8
# 14         15           13
# 0           1            1
# 36         37           13
# 12         13            6
# 44         45           16
# 26         27           10
# 24         25           13
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   store_nbr    45 non-null     int64
#  1   station_nbr  45 non-null     int64
# dtypes: int64(2)
# memory usage: 848.0 bytes
# None
#        store_nbr  station_nbr
# count  45.000000    45.000000
# mean   23.000000    11.266667
# std    13.133926     5.019960
# min     1.000000     1.000000
# 25%    12.000000     7.000000
# 50%    23.000000    12.000000
# 75%    34.000000    15.000000
# max    45.000000    20.000000

# %%
sns.scatterplot(x= "snowfall", y= "station_nbr", data = weather)
plt.show()
